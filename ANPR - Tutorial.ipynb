# %% [markdown]
# ## 0. Install and Import Dependencies

# %%
# %pip install easyocr
# %pip install imutils
# Out:
# Collecting easyocr
#   Using cached easyocr-1.7.0-py3-none-any.whl (2.9 MB)
# Requirement already satisfied: opencv-python-headless in c:\users\mayup\anaconda3\lib\site-packages (from easyocr) (4.7.0.72)
# Requirement already satisfied: python-bidi in c:\users\mayup\anaconda3\lib\site-packages (from easyocr) (0.4.2)
# Collecting torch
#   Using cached torch-2.0.1-cp39-cp39-win_amd64.whl (172.4 MB)
# Requirement already satisfied: ninja in c:\users\mayup\anaconda3\lib\site-packages (from easyocr) (1.11.1)
# Requirement already satisfied: scipy in c:\users\mayup\anaconda3\lib\site-packages (from easyocr) (1.9.1)
# Collecting torchvision>=0.5
#   Using cached torchvision-0.15.2-cp39-cp39-win_amd64.whl (1.2 MB)
# Requirement already satisfied: Shapely in c:\users\mayup\anaconda3\lib\site-packages (from easyocr) (2.0.1)
# Requirement already satisfied: numpy in c:\users\mayup\anaconda3\lib\site-packages (from easyocr) (1.21.5)
# Requirement already satisfied: Pillow in c:\users\mayup\anaconda3\lib\site-packages (from easyocr) (9.2.0)
# Requirement already satisfied: scikit-image in c:\users\mayup\anaconda3\lib\site-packages (from easyocr) (0.19.2)
# Requirement already satisfied: pyclipper in c:\users\mayup\anaconda3\lib\site-packages (from easyocr) (1.3.0.post4)
# Requirement already satisfied: PyYAML in c:\users\mayup\anaconda3\lib\site-packages (from easyocr) (6.0)
# Requirement already satisfied: requests in c:\users\mayup\anaconda3\lib\site-packages (from torchvision>=0.5->easyocr) (2.28.1)
# Requirement already satisfied: typing-extensions in c:\users\mayup\anaconda3\lib\site-packages (from torch->easyocr) (4.3.0)
# Requirement already satisfied: networkx in c:\users\mayup\anaconda3\lib\site-packages (from torch->easyocr) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\mayup\anaconda3\lib\site-packages (from torch->easyocr) (2.11.3)
# Requirement already satisfied: filelock in c:\users\mayup\anaconda3\lib\site-packages (from torch->easyocr) (3.6.0)
# Requirement already satisfied: sympy in c:\users\mayup\anaconda3\lib\site-packages (from torch->easyocr) (1.10.1)
# Requirement already satisfied: six in c:\users\mayup\anaconda3\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\mayup\anaconda3\lib\site-packages (from scikit-image->easyocr) (2.19.3)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\mayup\anaconda3\lib\site-packages (from scikit-image->easyocr) (2021.7.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\mayup\anaconda3\lib\site-packages (from scikit-image->easyocr) (21.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\mayup\anaconda3\lib\site-packages (from scikit-image->easyocr) (1.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\mayup\anaconda3\lib\site-packages (from packaging>=20.0->scikit-image->easyocr) (3.0.9)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\mayup\anaconda3\lib\site-packages (from jinja2->torch->easyocr) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mayup\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mayup\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mayup\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\mayup\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.0.4)
# Requirement already satisfied: mpmath>=0.19 in c:\users\mayup\anaconda3\lib\site-packages (from sympy->torch->easyocr) (1.2.1)
# Installing collected packages: torch, torchvision, easyocr
# Successfully installed easyocr-1.7.0 torch-2.0.1 torchvision-0.15.2
# Note: you may need to restart the kernel to use updated packages.
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py): started
#   Building wheel for imutils (setup.py): finished with status 'done'
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25847 sha256=b48d421469b9e8933235e1da24c917872f6d956f104166446de310f77eaa6bc7
#   Stored in directory: c:\users\mayup\appdata\local\pip\cache\wheels\4b\a5\2d\4a070a801d3a3d93f033d3ee9728f470f514826e89952df3ea
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import imutils
import easyocr

# %% [markdown]
# ## 1. Read in Image, Grayscale and Blur

# %%
img = cv2.imread('image3.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## 2. Apply filter and find edges for localization

# %%
bfilter = cv2.bilateralFilter(gray, 11, 17, 17) #Noise reduction
edged = cv2.Canny(bfilter, 30, 200) #Edge detection
plt.imshow(cv2.cvtColor(edged, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## 3. Find Contours and Apply Mask

# %%
keypoints = cv2.findContours(edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
contours = imutils.grab_contours(keypoints)
contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10]

# %%
location = None
for contour in contours:
    approx = cv2.approxPolyDP(contour, 10, True)
    if len(approx) == 4:
        location = approx
        break

# %%
location
# Out:
# array([[[263, 334]],
#
#        [[264, 363]],
#
#        [[369, 362]],
#
#        [[366, 333]]], dtype=int32)

# %%
mask = np.zeros(gray.shape, np.uint8)
new_image = cv2.drawContours(mask, [location], 0,255, -1)
new_image = cv2.bitwise_and(img, img, mask=mask)

# %%
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))

# %%
(x,y) = np.where(mask==255)
(x1, y1) = (np.min(x), np.min(y))
(x2, y2) = (np.max(x), np.max(y))
cropped_image = gray[x1:x2+1, y1:y2+1]

# %%
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## 4. Use Easy OCR To Read Text

# %%
reader = easyocr.Reader(['en'])
result = reader.readtext(cropped_image)
result
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# [([[0, 2], [107, 2], [107, 31], [0, 31]], 'EBJY. 982]', 0.374194031930304)]

# %% [markdown]
# ## 5. Render Result

# %%
text = result[0][-2]
font = cv2.FONT_HERSHEY_SIMPLEX
res = cv2.putText(img, text=text, org=(approx[0][0][0], approx[1][0][1]+60), fontFace=font, fontScale=1, color=(0,255,0), thickness=2, lineType=cv2.LINE_AA)
res = cv2.rectangle(img, tuple(approx[0][0]), tuple(approx[2][0]), (0,255,0),3)
plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))
